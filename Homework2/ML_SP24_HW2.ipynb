# %% [markdown]
# # ML_SP23_HW2 (DIY Decision Tree)

# %% [markdown]
# ### Due Date: 4/7 23:59 pm

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('data/breast_cancer.csv')
X = df.drop(['diagnosis'], axis=1).to_numpy()
# B is benign and is encoded as 0, M is maligant and is encoded as 1
y = df['diagnosis'].apply(lambda x: 1 if x == 'M' else 0).to_numpy()

# %%
df.head()
# Out:
#   diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0         M        17.99         10.38          122.80     1001.0
# 1         M        20.57         17.77          132.90     1326.0
# 2         M        19.69         21.25          130.00     1203.0
# 3         M        11.42         20.38           77.58      386.1
# 4         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    symmetry_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# 0         0.2419  ...         25.38          17.33           184.60
# 1         0.1812  ...         24.99          23.41           158.80
# 2         0.2069  ...         23.57          25.53           152.50
# 3         0.2597  ...         14.91          26.50            98.87
# 4         0.1809  ...         22.54          16.67           152.20
#
#    area_worst  smoothness_worst  compactness_worst  concavity_worst  \
# 0      2019.0            0.1622             0.6656           0.7119
# 1      1956.0            0.1238             0.1866           0.2416
# 2      1709.0            0.1444             0.4245           0.4504
# 3       567.7            0.2098             0.8663           0.6869
# 4      1575.0            0.1374             0.2050           0.4000
#
#    concave points_worst  symmetry_worst  fractal_dimension_worst
# 0                0.2654          0.4601                  0.11890
# 1                0.1860          0.2750                  0.08902
# 2                0.2430          0.3613                  0.08758
# 3                0.2575          0.6638                  0.17300
# 4                0.1625          0.2364                  0.07678
#
# [5 rows x 31 columns]

# %%
df.describe()
# Out:
#        radius_mean  texture_mean  perimeter_mean    area_mean  \
# count   569.000000    569.000000      569.000000   569.000000
# mean     14.127292     19.289649       91.969033   654.889104
# std       3.524049      4.301036       24.298981   351.914129
# min       6.981000      9.710000       43.790000   143.500000
# 25%      11.700000     16.170000       75.170000   420.300000
# 50%      13.370000     18.840000       86.240000   551.100000
# 75%      15.780000     21.800000      104.100000   782.700000
# max      28.110000     39.280000      188.500000  2501.000000
#
#        smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# count       569.000000        569.000000      569.000000           569.000000
# mean          0.096360          0.104341        0.088799             0.048919
# std           0.014064          0.052813        0.079720             0.038803
# min           0.052630          0.019380        0.000000             0.000000
# 25%           0.086370          0.064920        0.029560             0.020310
# 50%           0.095870          0.092630        0.061540             0.033500
# 75%           0.105300          0.130400        0.130700             0.074000
# max           0.163400          0.345400        0.426800             0.201200
#
#        symmetry_mean  fractal_dimension_mean  ...  radius_worst  \
# count     569.000000              569.000000  ...    569.000000
# mean        0.181162                0.062798  ...     16.269190
# std         0.027414                0.007060  ...      4.833242
# min         0.106000                0.049960  ...      7.930000
# 25%         0.161900                0.057700  ...     13.010000
# 50%         0.179200                0.061540  ...     14.970000
# 75%         0.195700                0.066120  ...     18.790000
# max         0.304000                0.097440  ...     36.040000
#
#        texture_worst  perimeter_worst   area_worst  smoothness_worst  \
# count     569.000000       569.000000   569.000000        569.000000
# mean       25.677223       107.261213   880.583128          0.132369
# std         6.146258        33.602542   569.356993          0.022832
# min        12.020000        50.410000   185.200000          0.071170
# 25%        21.080000        84.110000   515.300000          0.116600
# 50%        25.410000        97.660000   686.500000          0.131300
# 75%        29.720000       125.400000  1084.000000          0.146000
# max        49.540000       251.200000  4254.000000          0.222600
#
#        compactness_worst  concavity_worst  concave points_worst  \
# count         569.000000       569.000000            569.000000
# mean            0.254265         0.272188              0.114606
# std             0.157336         0.208624              0.065732
# min             0.027290         0.000000              0.000000
# 25%             0.147200         0.114500              0.064930
# 50%             0.211900         0.226700              0.099930
# 75%             0.339100         0.382900              0.161400
# max             1.058000         1.252000              0.291000
#
#        symmetry_worst  fractal_dimension_worst
# count      569.000000               569.000000
# mean         0.290076                 0.083946
# std          0.061867                 0.018061
# min          0.156500                 0.055040
# 25%          0.250400                 0.071460
# 50%          0.282200                 0.080040
# 75%          0.317900                 0.092080
# max          0.663800                 0.207500
#
# [8 rows x 30 columns]

# %%
sns.countplot(x='diagnosis',data=df, palette='RdBu_r')
# Out:
# <Axes: xlabel='diagnosis', ylabel='count'>

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)

# %% [markdown]
# ### First build the model with the standard sklearn library

# %%
from sklearn.tree import DecisionTreeClassifier
model = DecisionTreeClassifier(max_depth=10)
model.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(max_depth=10)

# %%
from sklearn.metrics import classification_report,confusion_matrix,accuracy_score
predictions = model.predict(X_test)
print(confusion_matrix(y_test,predictions))
print(classification_report(y_test,predictions))
print(accuracy_score(y_test, predictions))
# Out:
# [[70  2]
#  [ 3 39]]
#               precision    recall  f1-score   support
#
#            0       0.96      0.97      0.97        72
#            1       0.95      0.93      0.94        42
#
#     accuracy                           0.96       114
#    macro avg       0.96      0.95      0.95       114
# weighted avg       0.96      0.96      0.96       114
#
# 0.956140350877193

# %% [markdown]
# ### Second use the implementation of the blog to build the model

# %% [markdown]
# https://towardsdatascience.com/implementing-a-decision-tree-from-scratch-f5358ff9c4bb

# %%
from decision_tree_orig import DecisionTree
model = DecisionTree(max_depth=10)
model.fit(X_train, y_train)
# Out:
# Done fitting

# %%
from decision_tree_orig import accuracy_score
predictions = model.predict(X_test)
print(accuracy_score(y_test, predictions))
# Out:
# 0.9473684210526315

# %% [markdown]
# ### Note that the original implementation will not work if y is a categorical variable and it is expecting numpy array instead of DataFrame

# %%
X = df.drop(['diagnosis'], axis=1).to_numpy()
# without mapping M and B to 1 and 0, it will not work with the original code
#y = df['diagnosis'].apply(lambda x: 1 if x == 'M' else 0).to_numpy()
y = df['diagnosis'].to_numpy()
y[:10]
# Out:
# array(['M', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M'], dtype=object)

# %% [markdown]
# ***You will see an error below***

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)
model.fit(X_train, y_train)
print(accuracy_score(y_test, predictions,))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 2
#       1 X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)
# ----> 2 model.fit(X_train, y_train)
#       3 print(accuracy_score(y_test, predictions,))
#
# File ~/Machine Learning/decision_tree_orig.py:37, in DecisionTree.fit(self, X, y)
#      36 def fit(self, X, y):
# ---> 37     self.root = self._build_tree(X, y)
#      38     print("Done fitting")
#
# File ~/Machine Learning/decision_tree_orig.py:65, in DecisionTree._build_tree(self, X, y, depth)
#      62 # get best split
#      63 rnd_feats = np.random.choice(self.n_features, self.n_features, replace=False)
# ---> 65 best_feat, best_thresh = self._best_split(X, y, rnd_feats)
#      67 # grow children recursively
#      68 left_idx, right_idx = self._create_split(X[:, best_feat], best_thresh)
#
# File ~/Machine Learning/decision_tree_orig.py:102, in DecisionTree._best_split(self, X, y, features)
#     100 thresholds = np.unique(X_feat)
#     101 for thresh in thresholds:
# --> 102     score = self._information_gain(X_feat, y, thresh)
#     104     if score > split['score']:
#     105         split['score'] = score
#
# File ~/Machine Learning/decision_tree_orig.py:85, in DecisionTree._information_gain(self, X, y, thresh)
#      84 def _information_gain(self, X, y, thresh):
# ---> 85     parent_loss = self._entropy(y)
#      86     left_idx, right_idx = self._create_split(X, thresh)
#      87     n, n_left, n_right = len(y), len(left_idx), len(right_idx)
#
# File ~/Machine Learning/decision_tree_orig.py:75, in DecisionTree._entropy(self, y)
#      74 def _entropy(self, y):
# ---> 75     proportions = np.bincount(y) / len(y)
#      76     entropy = -np.sum([p * np.log2(p) for p in proportions if p > 0])
#      77     return entropy
#
# TypeError: Cannot cast array data from dtype('O') to dtype('int64') according to the rule 'safe'

# %% [markdown]
# ### Finally use your own improved implementation to build the model

# %% [markdown]
# ***Show below that your version can handle both integer or categorical variable***

# %%
from decision_tree import DecisionTreeModel
# replace the above with your version
model = DecisionTreeModel(max_depth=10)

X = df.drop(['diagnosis'], axis=1).to_numpy()
# Your implementation should allow the target variable to be also categorical variable, ie y being B or M
#y = df['diagnosis'].apply(lambda x: 1 if x == 'M' else 0).to_numpy()
y = df['diagnosis'].to_numpy()
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)

# %%
y_train[:10]
# Out:
# array(['M', 'M', 'B', 'B', 'B', 'B', 'B', 'M', 'M', 'B'], dtype=object)

# %%
model.fit(X_train, y_train)
predictions = model.predict(X_test)
print(accuracy_score(y_test, predictions))
# Out:
# Done fitting
# 0.9385964912280702

# %% [markdown]
# ### Call your own performance report

# %%
from decision_tree import classification_report,confusion_matrix,accuracy_score
predictions = model.predict(X_test)
print(confusion_matrix(y_test,predictions))
print(classification_report(y_test,predictions))
print(accuracy_score(y_test, predictions))
# Out:
# [[38  3]
#  [ 4 69]]
# {'Precision': 0.926829268292683, 'Recall': 0.9047619047619048, 'F1-Score': 0.9156626506024096}
# 0.9385964912280702

# %% [markdown]
# ### Try 3 different values for the impurity threshold for the Decision Tree Model. Comment on of the impact of the parameter (if there is any) on the model performance

# %%
# Type your code here
def experiment_with_impurity_thresholds(X_train, X_test, y_train, y_test, impurity_thresholds):
    for threshold in impurity_thresholds:
        clf = DecisionTreeModel(max_depth=10, criterion='gini', impurity_stopping_threshold=threshold)
        clf.fit(X_train, y_train)
        y_pred = clf.predict(X_test)
        acc = accuracy_score(y_test, y_pred)
        print(f"Impurity Threshold: {threshold}, Accuracy: {acc}")

# Define impurity thresholds to experiment with
impurity_thresholds = [0.1, 0.05, 0.01]

# Perform experiment
experiment_with_impurity_thresholds(X_train, X_test, y_train, y_test, impurity_thresholds)
# Out:
# Done fitting
# Impurity Threshold: 0.1, Accuracy: 0.9298245614035088
# Done fitting
# Impurity Threshold: 0.05, Accuracy: 0.9210526315789473
# Done fitting
# Impurity Threshold: 0.01, Accuracy: 0.9385964912280702

# %% [markdown]
# ### Finally call your RandomForest Model just like the standard sklearn library

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report,confusion_matrix,accuracy_score

rfc = RandomForestClassifier(n_estimators=100)
rfc.fit(X_train, y_train)
rfc_pred = rfc.predict(X_test)
print(classification_report(y_test, rfc_pred))
print(accuracy_score(y_test, rfc_pred))
# Out:
#               precision    recall  f1-score   support
#
#            B       0.94      1.00      0.97        72
#            M       1.00      0.88      0.94        42
#
#     accuracy                           0.96       114
#    macro avg       0.97      0.94      0.95       114
# weighted avg       0.96      0.96      0.96       114
#
# 0.956140350877193

# %%
# Type your code here
from decision_tree import RandomForestModel
from decision_tree import classification_report,confusion_matrix,accuracy_score

# 100 can take a while, so you can use smaller value when you are testing
rfc = RandomForestModel(n_estimators=100)
rfc.fit(X_train, y_train)
rfc_pred = rfc.predict(X_test)
print(classification_report(y_test, rfc_pred))
print(accuracy_score(y_test, rfc_pred))
# Out:
# Done fitting
# Done fitting
# Done fitting
# Done fitting
# Done fitting
# Done fitting
# Done fitting
# Done fitting
# Done fitting
# Done fitting
# Done fitting
# Done fitting
# Done fitting
# Done fitting
# Done fitting
# Done fitting
# Done fitting
# Done fitting
# Done fitting
# Done fitting
# Done fitting
# Done fitting
# Done fitting
# Done fitting
# Done fitting
# Done fitting
# Done fitting
# Done fitting
# Done fitting
# Done fitting
# Done fitting
# Done fitting
# Done fitting
# Done fitting
# Done fitting
# Done fitting
# Done fitting
# Done fitting
# Done fitting
# Done fitting
# Done fitting
# Done fitting
# Done fitting
# Done fitting
# Done fitting
# Done fitting
# Done fitting
# Done fitting
# Done fitting
# Done fitting
# Done fitting
# Done fitting
# Done fitting
# Done fitting
# Done fitting
# Done fitting
# Done fitting
# Done fitting
# Done fitting
# Done fitting
# Done fitting
# Done fitting
# Done fitting
# Done fitting
# Done fitting
# Done fitting
# Done fitting
# Done fitting
# Done fitting
# Done fitting
# Done fitting
# Done fitting
# Done fitting
# Done fitting
# Done fitting
# Done fitting
# Done fitting
# Done fitting
# Done fitting
# Done fitting
# Done fitting
# Done fitting
# Done fitting
# Done fitting
# Done fitting
# Done fitting
# Done fitting
# Done fitting
# Done fitting
# Done fitting
# Done fitting
# Done fitting
# Done fitting
# Done fitting
# Done fitting
# Done fitting
# Done fitting
# Done fitting
# Done fitting
# Done fitting
# {'Precision': 0.9743589743589743, 'Recall': 0.9047619047619048, 'F1-Score': 0.9382716049382716}
# 0.956140350877193
